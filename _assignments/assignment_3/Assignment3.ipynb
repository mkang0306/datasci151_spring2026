# %% [markdown]
# # <span style="color:red"> Assignment 3 - Due Thursday, February 12th at 8am ET</span>

# %% [markdown]
# #### Complete the code cells in this Jupyter notebook, and submit the final .ipynb notebook to Gradescope.
#
# #### Please do the following in VS code before you submit:
#
# - #### Click "Clear All Outputs"
#
# - #### Click "Restart"
#
# - #### Run all code cells
#
# - #### Save the file
#
# #### **Note:** Output should match the code that appears in its corresponding cell.

# %% [markdown]
# <font size = "3">
#
# Import any modules you need in the cell below

# %%
# import any necessary modules/packages

import math
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <font size = "4">
#
# (a) **(Q1)** Compute a geometric formula:
#
# <font size = "3">
#
# The **frustum** of a cone is the shape formed when the top of a cone is cut off parallel to the base, leaving two circular faces of different radii. (Think of a lampshade or a bucket)
#
# The formula for the volume of a frustum of a cone is:
#
#
# $$V = \frac{1}{3}\pi h (r_1^2 + r_1 r_2 + r_2^2)$$
#
#
# Where:
#
# - $V$ is the volume of the cylinder
# - $r_1$ is the radius of the bottom base
# - $r_2$ is the radius of the top base
# - $h$ is the height of the frustrum
#
# Calculate $V$ when:
#
# - $r_1 = 6$
# - $r_2 = 3$
# - $h = 10$
#
#
# To get full points:
# - Define Python variables corresponding to the values of $r_1$, $r_2$, and $h$ above.
#
# - Use your variables to calculate the volume ($V$) using the formula above. This value should also be assigned to a variable.
#
# - Print out the value of the computed volume to the screen.

# %%
# define variables corresponding to values of r1, r2, h
radius1 = 6
radius2 = 3
height = 10

# calculate volume of frustum by inputting variables
volume = (1/3) * math.pi * height * (radius1**2 + radius1 * radius2 + radius2**2)

# print output
print(volume)
# Out:
# 659.7344572538565

# %% [markdown]
# <font size = "4">
#
# **(Q2)** Operations on Arrays
#
# <font size = "3">
#
# - Define an array `temps_c` using `numpy.array()`, assigning the following values of temperatures measured in degrees Celsius: <br> <br>`temps_c` $= \begin{pmatrix} c_1 \\ c_2 \\ c_3 \\ c_4 \\ c_5 \end{pmatrix} = \begin{pmatrix} 0 \\ 10 \\ 20 \\ 30 \\ 40 \end{pmatrix}$ <br> <br>
# - Use element-by-element vector operations to compute a new array `temps_f` of the same size, converting the temperatures from Celsius to Fahrenheit: <br><br>
# `temps_f` $= \begin{pmatrix} f_1 \\[8pt] f_2 \\[8pt] f_3 \\[8pt] f_4 \\[8pt] f_5 \end{pmatrix} = \begin{pmatrix} c_1 \times \tfrac{9}{5} +32 \\[8pt] c_2 \times \tfrac{9}{5} +32 \\[8pt] c_3 \times \tfrac{9}{5} + 32 \\[8pt] c_4 \times \tfrac{9}{5} + 32 \\[8pt] c_5 \times \tfrac{9}{5} + 32\end{pmatrix} $ <br><br>
# - Print the value of `temps_f` to the screen.
# - Compute and print the average of the Fahrenheit temperatures. Do not "manually" compute it, use a NumPy function or method

# %%
# define celsius array
temps_c = np.array([0, 10, 20, 30, 40])

# convert to fahrenheit using vector operations
temps_f = temps_c * 9/5 + 32

# print fahrenheit values
print(temps_f)

# compute and print average fahrenheit temperatures
print(np.mean(temps_f))
# Out:
# [ 32.  50.  68.  86. 104.]
# 68.0

# %% [markdown]
# <font size = "4">
#
# **(Q3)** Create a histogram of a Normal random Variable
#
# <font size = "3">
#
# Review the "lecture_07-supplement.ipynb". In particular, you will need to be familiar with the section title "Numpy Arrays of Random Numbers"
#
# - Use `numpy.random.seed` to ensure reproducible results. Use a seed value of `1234`
#
# - Generate a sample of a **normal** random variable.
#     - Set the mean value of the normal random variable to be 7
#     - Set the standard deviation to be 5
#     - The sample size should be $1,500$ (one thousand five hundred)
#
# - Create a histogram of the drawn sample.
#
# - Label both axes and add a title to the histogram.
#
# - Ensure that no extraneous text appears by calling `plt.show()`

# %%
# set the seed for reproducability
np.random.seed(1234)

# generate normal sample with given constraints
sample = np.random.normal(loc = 7, scale = 5, size = 1500)

# create histogram
plt.hist(sample)

# label axes and title
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Histogram of Normal Random Variable")

# show plot
plt.show()

# %% [markdown]
# <font size = "4">
#
# **(Q4)** Checking if a word belongs to a list
#
# <font size = "3">
#
# - Define a variable named `skill_1` assigning the string "Python"
#
# - Define a variable `skill_2` assigning the string "SQL"
#
# - Create a list variable called `job_requirements` containing the strings "Python", "Excel", "Data Analysis", and "Communication".
#
# - Define logical expressions that test whether `skill_1` and `skill_2` are elements of the list `job_requirements`. Print the value of both expression to the screen

# %%
# define variables
skill_1 = "Python"
skill_2 = "SQL"

# create list for job requirements
job_requirements = ["Python", "Excel", "Data Analysis", "Communication"]

# logical expressions checking if variables are in list
check_1 = skill_1 in job_requirements
check_2 = skill_2 in job_requirements

# print results
print(check_1)
print(check_2)
# Out:
# True
# False

# %% [markdown]
# <font size = "4">
#
# **(Q5)** Classifying a Variable
#
# <font size = "3">
#
# - Below, the variable `final_grade` is assigned a random value between 0 and 100
# - Write an if/elif/else statement that does the following
#   - Prints the string `"A"` to the screen if the rating is **greater than or equal to 87**.
#   - Prints the string `"B"` to the screen if the rating is **greater than or equal to 75 but less than 87**.
#   - Prints the string `"C"` to the screen if the rating is **greater than or equal to 60 but less than 75**.
#   - Prints the string `"D"` to the screen if the rating is **greater than or equal to 55 but less than 60**.
#   - Prints the string `"F"` to the screen otherwise.
#
# You may want to also print the value of `final_grade` to the screen to check your code is behaving as expected.

# %%
import numpy as np 
final_grade = np.random.uniform(low = 0, high = 100)

# print actual number
print(final_grade)

# classifies number into grade distribution
if final_grade >= 87:
    print("A")
elif final_grade >= 75:
    print("B")
elif final_grade >= 60:
    print("C")
elif final_grade >= 55:
    print("D")
else:
    print("F")
# Out:
# 20.53341366949637
# F

# %% [markdown]
# <font size = "4">
#
# **(Q6)** Generating random values on a computer.
#
# <font size = "3">
#
# Random* values are often generated on a computer by first generating a uniform random variable between 0 and 1, and then transforming it to another value in some manner.
#
# For example, to simulate a coin toss we can generate a random number $0 < x < 1$ and check if it is less than $0.5$. If it is, we have flipped "Heads". Otherwise we have flipped "Tails".
#
# This models a "fair" coin, where the probability of flipping Heads is 0.5 (a 50% chance). But we could simulate an "unfair" coin, where the probability of flipping Heads is smaller or larger than 0.5.
#
# Write code that does the following:
#
# - Define a variable `p` that is greater than 0 but less than 1. This is the probability of obtaining Heads. It's your choice what value to set it to.
#
# - Use the function `numpy.random.uniform` to randomly generate a variable `x` that lies between 0 and 1.
#
# - Write code that checks if `x` is smaller than `p`. If so, the code should print the string "The flip was Heads". Otherwise, the code should print the string "The flips was Tails".
#
#
# <font size = "2">
#
# \* Strictly speaking, the majority of computers can only generate *pseudo-random* numbers, not actual random numbers.

# %%
# probability of getting heads
p = 0.5

# generate random number between 0 and 1
x = np.random.uniform(0,1)

# check outcome
if x < p:
    print("The flip was Heads")

else:
    print("The flip was Tails")

# double check with output
print("x = ", x)
# Out:
# The flip was Tails
# x =  0.8831822328409942
